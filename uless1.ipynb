# %% [markdown]
# Введение в Jupyter

# %% [markdown]
#  Что мы сегодня будем делать?
# * Разберемся с типами ячеек
# * Поработаем с данными в формате .csv

# %%
# !chcp 1251
# Out:
# ’ҐЄгй п Є®¤®ў п бва ­Ёж : 1251

# %%
import csv

# %%
streets = {}

# %%
# %time
with open('bus_stops.csv', 'r', encoding='cp1251') as f:
    reader = csv.DictReader(f, delimiter=';')
    for row in reader:
        if row['Street'] in streets:
            streets[row['Street']] += 1
        else:
            streets[row['Street']] = 1
# Out:
# Wall time: 0 ns

# %%
streets
# Out:
# {'3-й Дербеневский переулок': 4,
#  'набережная Тараса Шевченко': 4,
#  '3-я Черепковская улица': 10,
#  'улица Сущёвский Вал': 32,
#  'Дубнинская улица': 60,
#  'улица 800-летия Москвы': 26,
#  'Дмитровское шоссе': 152,
#  'Локомотивный проезд': 16,
#  'Большая Академическая улица': 50,
#  'улица Зои и Александра Космодемьянских': 28,
#  'Ангарская улица': 34,
#  'Коровинское шоссе': 48,
#  'Клязьминская улица': 24,
#  'улица Линии Октябрьской Железной Дороги': 12,
#  'Старопетровский проезд': 20,
#  'улица Клары Цеткин': 10,
#  'Михалковская улица': 28,
#  'Онежская улица': 22,
#  'Петрозаводская улица': 18,
#  'Беломорская улица': 18,
#  'Смольная улица': 38,
#  'Фестивальная улица': 62,
#  'Бескудниковский бульвар': 44,
#  'Коптевский бульвар': 8,
#  'Коптевская улица': 24,
#  'Кронштадтский бульвар': 42,
#  'Нарвская улица': 12,
#  '3-й Лихачёвский переулок': 2,
#  '4-й Лихачёвский переулок': 4,
#  'Автомоторная улица': 12,
#  '4-й Новомихалковский проезд': 8,
#  'Митинская улица': 28,
#  'улица Дыбенко': 26,
#  'Зеленоградская улица': 24,
#  'улица Академика Курчатова': 8,
#  'Сосновая улица': 6,
#  'Пехотная улица': 4,
#  '1-й Волоколамский проезд': 8,
#  'улица Усиевича': 8,
#  'Планетная улица': 14,
#  'Петровско-Разумовская аллея': 12,
#  'Часовая улица': 8,
#  '2-й Пехотный переулок': 4,
#  'Авангардная улица': 12,
#  'Флотская улица': 26,
#  'Солнечногорская улица': 12,
#  'Сенежская улица': 4,
#  'улица Прянишникова': 10,
#  'Тимирязевская улица': 44,
#  'улица Вучетича': 12,
#  '2-я Хуторская улица': 8,
#  'Петровско-Разумовский проезд': 16,
#  'Ижорская улица': 12,
#  'улица Бусиновская Горка': 8,
#  'Краснополянская улица': 10,
#  'улица Лавочкина': 10,
#  'Бутырская улица': 28,
#  'улица Бутырский Вал': 16,
#  'Новослободская улица': 16,
#  'Волоколамское шоссе': 104,
#  'Херсонская улица': 20,
#  'Ленинградский проспект': 74,
#  'Ботаническая улица': 28,
#  'улица Академика Королёва': 34,
#  'Новомосковская улица': 14,
#  'Звёздный бульвар': 10,
#  '6-й Новоостанкинский проезд': 2,
#  'улица Цандера': 4,
#  'улица Кондратюка': 2,
#  'проспект Мира': 148,
#  'Сусоколовское шоссе': 4,
#  'улица Героев Панфиловцев': 74,
#  'Сходненская улица': 34,
#  'Лодочная улица': 26,
#  'улица Свободы': 72,
#  'Авиационная улица': 28,
#  'улица Маршала Федоренко': 12,
#  'улица Лужники': 6,
#  'Лужнецкая набережная': 6,
#  'Лужнецкий проезд': 4,
#  'Большая Пироговская улица': 24,
#  'улица Плющиха': 16,
#  'улица Хамовнический Вал': 12,
#  'Смоленская-Сенная площадь': 4,
#  'Новинский бульвар': 8,
#  'улица Красная Пресня': 18,
#  'улица 1905 Года': 8,
#  'Хорошёвское шоссе': 46,
#  'Кудринская площадь': 4,
#  'улица Еланского': 2,
#  'Станционная улица': 10,
#  'Красностуденческий проезд': 10,
#  'Смоленский бульвар': 8,
#  'улица Берзарина': 24,
#  'улица Расплетина': 10,
#  'улица Маршала Бирюзова': 32,
#  'улица Василия Петушкова': 22,
#  'Светлогорский проезд': 8,
#  'Гостиничная улица': 2,
#  'Башиловская улица': 16,
#  'улица Расковой': 8,
#  '5-я улица Ямского Поля': 4,
#  '1-я улица Ямского Поля': 4,
#  'улица Нижняя Масловка': 16,
#  '3-й Нижнелихоборский проезд': 8,
#  'улица Исаковского': 28,
#  'улица Маршала Катукова': 32,
#  'Рублёвское шоссе': 82,
#  'улица Кулакова': 34,
#  '2-я Квесисская улица': 10,
#  'Мякининский проезд': 4,
#  '2-й Крестовский переулок': 2,
#  'Рижская площадь': 6,
#  '4-й Вятский переулок': 10,
#  'Старый Петровско-Разумовский проезд': 8,
#  'Ленинградское шоссе': 124,
#  'бульвар Яна Райниса': 36,
#  'Химкинский бульвар': 12,
#  'улица Костякова': 16,
#  'улица Куусинена': 22,
#  'улица Маршала Тухачевского': 22,
#  'улица Народного Ополчения': 50,
#  'улица Саляма Адиля': 6,
#  'Карамышевская набережная': 20,
#  'улица Мнёвники': 18,
#  'проспект Маршала Жукова': 42,
#  'Таманская улица': 28,
#  'Карамышевский проезд': 4,
#  'улица Константина Царёва': 16,
#  'Звенигородское шоссе': 20,
#  '1-й Новоподмосковный переулок': 4,
#  'Проспект Маршала Жукова': 6,
#  'Песчаная площадь': 6,
#  'Новопесчаная улица': 16,
#  'Анадырский проезд': 20,
#  'улица Малыгина': 18,
#  'Изумрудная улица': 20,
#  'Минусинская улица': 6,
#  'улица Коминтерна': 22,
#  'Радужная улица': 20,
#  'Енисейская улица': 46,
#  'проезд Серебрякова': 22,
#  'улица Амундсена': 4,
#  'Туристская улица': 22,
#  'Походный проезд': 14,
#  'Строительный проезд': 8,
#  'проезд Донелайтиса': 16,
#  'улица Фабрициуса': 20,
#  'Вишнёвая улица': 6,
#  'улица Генерала Белобородова': 30,
#  'площадь Академика Курчатова': 6,
#  'улица Маршала Конева': 4,
#  'улица Алабяна': 14,
#  'улица Черняховского': 2,
#  'улица Маршала Василевского': 16,
#  'Песчаная улица': 8,
#  'проезд Девичьего Поля': 2,
#  'Смоленская площадь': 4,
#  'площадь Новодевичьего Монастыря': 6,
#  'Ельнинская улица': 16,
#  'проезд без названия': 1514,
#  'улица Генерала Глаголева': 12,
#  'Планерная улица': 28,
#  'Снежная улица': 20,
#  'проезд Соломенной Сторожки': 6,
#  'Алёшкинский проезд': 4,
#  'улица Корнейчука': 30,
#  'улица Лескова': 36,
#  'Широкая улица': 46,
#  'улица Бориса Галушкина': 26,
#  'Ростокинский проезд': 12,
#  'Богородское шоссе': 16,
#  'улица Максимова': 6,
#  'улица Рогова': 10,
#  'Талдомская улица': 8,
#  'Керамический проезд': 8,
#  'Весенняя улица': 6,
#  'Лобненская улица': 14,
#  'Карельский бульвар': 14,
#  'Живописная улица': 32,
#  'улица Паршина': 8,
#  'улица Маршала Соколовского': 4,
#  'улица Маршала Новикова': 10,
#  'улица Маршала Вершинина': 2,
#  'улица Твардовского': 22,
#  'Таллинская улица': 36,
#  'Новощукинская улица': 32,
#  'Street': 24,
#  'Дегунинский проезд': 2,
#  'проезд Стратонавтов': 8,
#  'Строгинское шоссе': 12,
#  'Тушинская площадь': 22,
#  'Одинцовская улица': 8,
#  'Туркменский проезд': 2,
#  'Строгинский бульвар': 18,
#  'Ижорский проезд': 6,
#  'Прибрежный проезд': 16,
#  'Неманский проезд': 16,
#  'Гостиничный проезд': 4,
#  'улица Космонавта Волкова': 14,
#  'улица Академика Бочвара': 4,
#  'улица Гамалеи': 12,
#  'улица Софьи Ковалевской': 18,
#  '74-й километр Московской Кольцевой Автодороги': 4,
#  '1-й Силикатный проезд': 16,
#  'Шелепихинское шоссе': 8,
#  '3-я Магистральная улица': 10,
#  '4-я Магистральная улица': 12,
#  'улица Нижние Мнёвники': 18,
#  'улица Сергея Эйзенштейна': 6,
#  'улица Вильгельма Пика': 10,
#  'Берёзовая аллея': 18,
#  'Олонецкая улица': 10,
#  'Отрадная улица': 8,
#  'Отрадный проезд': 6,
#  'Сигнальный проезд': 18,
#  'Продольный проезд': 38,
#  'улица Вилиса Лациса': 20,
#  'Причальный проезд': 4,
#  'Шелепихинская набережная': 8,
#  'Большая Филёвская улица': 32,
#  'Минская улица': 32,
#  'улица Фомичёвой': 8,
#  'Осенний бульвар': 20,
#  'улица Крылатские Холмы': 34,
#  'Рубежный проезд': 4,
#  'Беговая улица': 14,
#  'Магистральный переулок': 4,
#  '2-й Хорошёвский проезд': 10,
#  '5-я Магистральная улица': 2,
#  'улица Заморёнова': 14,
#  '3-я Хорошёвская улица': 20,
#  'Ярославское шоссе': 56,
#  '93-й километр Московской Кольцевой Автодороги': 4,
#  '92-й километр Московской Кольцевой Автодороги': 8,
#  '91-й километр Московской Кольцевой Автодороги': 4,
#  '89-й километр Московской Кольцевой Автодороги': 4,
#  '88-й километр Московской Кольцевой Автодороги': 4,
#  '87-й километр Московской Кольцевой Автодороги': 4,
#  '84-й километр Московской Кольцевой Автодороги': 4,
#  '83-й километр Московской Кольцевой Автодороги': 4,
#  'Лианозовский проезд': 10,
#  'Мелиховская улица': 6,
#  'Белозерская улица': 14,
#  'Мурановская улица': 12,
#  'улица Пришвина': 18,
#  'Бибиревская улица': 22,
#  'Алтуфьевское шоссе': 98,
#  'Костромская улица': 16,
#  'Череповецкая улица': 32,
#  'улица Ивана Сусанина': 14,
#  'Осенняя улица': 16,
#  'Крылатская улица': 40,
#  'Осташковская улица': 20,
#  'Псковская улица': 6,
#  'Зональная улица': 4,
#  'Барвихинская улица': 24,
#  'Запорожская улица': 2,
#  'улица Маршала Неделина': 14,
#  'улица Красных Зорь': 18,
#  'Малая Филёвская улица': 24,
#  'Пинский проезд': 4,
#  'улица Барклая': 36,
#  'улица Толбухина': 8,
#  'Можайское шоссе': 34,
#  'Аминьевское шоссе': 32,
#  'Верейская улица': 20,
#  'Рябиновая улица': 62,
#  '2-й Поперечный проезд': 4,
#  'Абрамцевская улица': 24,
#  'улица Плещеева': 16,
#  'улица Конёнкова': 14,
#  'Илимская улица': 12,
#  'улица Говорова': 12,
#  'Вяземская улица': 6,
#  'Сколковское шоссе': 26,
#  'Беловежская улица': 24,
#  'Ярцевская улица': 16,
#  'улица Артамонова': 10,
#  'улица Кубинка': 6,
#  'улица Боженко': 4,
#  'Варшавское шоссе': 380,
#  'Сумская улица': 10,
#  'Кировоградская улица': 58,
#  'улица Красного Маяка': 38,
#  'Вологодский проезд': 10,
#  'улица Лётчика Бабушкина': 34,
#  'улица Менжинского': 36,
#  'Северодвинская улица': 12,
#  'Волгоградский проспект': 106,
#  'Славянский бульвар': 14,
#  'Кременчугская улица': 8,
#  'Гвардейская улица': 6,
#  'Давыдковская улица': 16,
#  'Староможайское шоссе': 6,
#  'Кутузовский проспект': 76,
#  'Большая Дорогомиловская улица': 22,
#  'Бережковская набережная': 18,
#  'Воробьёвское шоссе': 8,
#  'Мосфильмовская улица': 40,
#  'Мичуринский проспект': 84,
#  'улица Косыгина': 28,
#  'Ленинский проспект': 150,
#  'улица Большая Якиманка': 10,
#  'Якиманский проезд': 4,
#  'улица Серафимовича': 6,
#  'Стартовая улица': 24,
#  'проезд Шокальского': 24,
#  'улица Грекова': 24,
#  'Студёный проезд': 16,
#  'проезд Дежнёва': 26,
#  'Тайнинская улица': 12,
#  'Новозаводская улица': 24,
#  'Береговой проезд': 4,
#  'Новофилёвский проезд': 8,
#  'Филёвский бульвар': 18,
#  'Полярная улица': 48,
#  'улица Молодцова': 16,
#  'Ясный проезд': 24,
#  'Северный бульвар': 16,
#  'улица Бестужевых': 14,
#  'Инженерная улица': 12,
#  'Путевой проезд': 16,
#  'улица Декабристов': 30,
#  'улица Хачатуряна': 24,
#  'улица Санникова': 4,
#  'улица Мусоргского': 10,
#  'Челюскинская улица': 12,
#  'Юрловский проезд': 22,
#  'Партизанская улица': 22,
#  'Истринская улица': 6,
#  'Молдавская улица': 8,
#  'Житомирская улица': 2,
#  'Кастанаевская улица': 36,
#  'Молодогвардейская улица': 36,
#  'Заревый проезд': 6,
#  'Сельскохозяйственная улица': 36,
#  'улица Пестеля': 8,
#  'Чертановская улица': 134,
#  'Симферопольский бульвар': 50,
#  'улица 26-ти Бакинских Комиссаров': 18,
#  'Селигерская улица': 2,
#  'Бескудниковский переулок': 2,
#  'улица Академика Янгеля': 12,
#  'Россошанский проезд': 8,
#  '3-й Дорожный проезд': 20,
#  'Дорожная улица': 44,
#  'улица Подольских Курсантов': 34,
#  'Мирской переулок': 10,
#  'Холмогорская улица': 4,
#  'Федоскинская улица': 8,
#  'улица Римского-Корсакова': 18,
#  'улица Яблочкова': 22,
#  'улица Фонвизина': 10,
#  'улица Милашенкова': 20,
#  'Россошанская улица': 8,
#  'Сумской проезд': 14,
#  '1-я Останкинская улица': 24,
#  'Кольская улица': 12,
#  'Чонгарский бульвар': 24,
#  'Днепропетровская улица': 28,
#  'Печорская улица': 10,
#  'улица Гончарова': 8,
#  'улица Руставели': 16,
#  'Огородный проезд': 24,
#  '17-й проезд Марьиной Рощи': 4,
#  'Шереметьевская улица': 26,
#  '5-й проезд Марьиной Рощи': 4,
#  'Полковая улица': 2,
#  'улица Двинцев': 8,
#  'улица Грузинский Вал': 8,
#  'улица Пресненский Вал': 16,
#  'улица Трёхгорный Вал': 2,
#  'Шмитовский проезд': 28,
#  '2-й Красногвардейский проезд': 4,
#  'Новый Берингов проезд': 8,
#  'улица Сергея Макеева': 4,
#  'Стрелецкая улица': 2,
#  '3-й проезд Марьиной Рощи': 4,
#  'Востряковский проезд': 26,
#  'Булатниковская улица': 18,
#  'Медынская улица': 22,
#  'Харьковская улица': 8,
#  'Булатниковский проезд': 24,
#  'Болотниковская улица': 44,
#  'Большая Тульская улица': 14,
#  'Подольское шоссе': 4,
#  'Павловская улица': 2,
#  'Большая Серпуховская улица': 18,
#  'Серпуховская площадь': 4,
#  'улица Большая Полянка': 16,
#  'Люсиновская улица': 16,
#  'улица Добролюбова': 8,
#  'улица Советской Армии': 12,
#  'Трифоновская улица': 24,
#  'Олимпийский проспект': 16,
#  'улица Дурова': 10,
#  'Самотёчная улица': 4,
#  'Малая Ботаническая улица': 4,
#  'Мясницкая улица': 8,
#  'Ростокинская улица': 10,
#  'Малахитовая улица': 16,
#  'улица Докукина': 14,
#  '1-я улица Леонова': 8,
#  '1-й Ботанический проезд': 2,
#  'Лазоревый проезд': 4,
#  '2-й Ботанический проезд': 4,
#  'улица Седова': 4,
#  'проезд Русанова': 14,
#  'Краснопролетарская улица': 12,
#  'Останкинский проезд': 4,
#  'Селезнёвская улица': 6,
#  'Нахимовский проспект': 66,
#  'Коломенская улица': 22,
#  'улица Новинки': 10,
#  'проспект Андропова': 54,
#  'Нагатинская набережная': 34,
#  'Судостроительная улица': 60,
#  '1-й Нагатинский проезд': 4,
#  'Нагатинская улица': 30,
#  'Ереванская улица': 18,
#  'Кавказский бульвар': 28,
#  'Пролетарский проспект': 48,
#  'Каширское шоссе': 122,
#  'улица Каховка': 36,
#  'улица Намёткина': 6,
#  'Профсоюзная улица': 114,
#  'Страстной бульвар': 6,
#  'Долгоруковская улица': 12,
#  'Большая Переяславская улица': 8,
#  'Каланчёвская улица': 18,
#  'Русаковская улица': 24,
#  'улица Стромынка': 28,
#  'Электрозаводская улица': 24,
#  'Ферганский проезд': 18,
#  'Самаркандский бульвар': 22,
#  'улица Хлобыстова': 34,
#  'Ташкентская улица': 26,
#  'улица Образцова': 8,
#  'Перуновский переулок': 2,
#  'улица Новая Башиловка': 8,
#  'Балаклавский проспект': 40,
#  'улица Обручева': 38,
#  'Ферганская улица': 18,
#  '2-й Грайвороновский проезд': 16,
#  'Грайвороновская улица': 14,
#  'Люблинская улица': 86,
#  'Черноморский бульвар': 18,
#  'Ялтинская улица': 4,
#  'Стрельбищенский переулок': 12,
#  'Артековская улица': 4,
#  'Оружейный переулок': 4,
#  'Садовая-Триумфальная улица': 4,
#  'улица Павла Корчагина': 16,
#  'Новоалексеевская улица': 8,
#  '3-я Мытищинская улица': 4,
#  'площадь Академика Люльки': 4,
#  'улица Сокольнический Вал': 24,
#  'Поперечный просек': 30,
#  'Краснобогатырская улица': 48,
#  'улица Измайловский Вал': 16,
#  'Семёновская площадь': 6,
#  'Щербаковская улица': 16,
#  'Измайловский проспект': 18,
#  'Первомайская улица': 86,
#  'улица Преображенский Вал': 10,
#  'улица Олений Вал': 8,
#  'Большая Ширяевская улица': 8,
#  'Миллионная улица': 8,
#  'Новорязанская улица': 12,
#  'Бакунинская улица': 22,
#  'Электрозаводский мост': 8,
#  'Вельяминовская улица': 8,
#  'Ткацкая улица': 16,
#  'Большая Оленья улица': 10,
#  'Халтуринская улица': 16,
#  'Большая Семёновская улица': 14,
#  'Спартаковская улица': 4,
#  'Ивантеевская улица': 30,
#  '4-й проезд Подбельского': 4,
#  '1-я Прогонная улица': 2,
#  'Малая Черкизовская улица': 6,
#  'Большая Черкизовская улица': 40,
#  'Просторная улица': 8,
#  'Алымов переулок': 2,
#  '3-я Гражданская улица': 4,
#  'Игральная улица': 6,
#  'улица Сайкина': 4,
#  'Велозаводская улица': 6,
#  'улица Ленинская Слобода': 8,
#  'улица Мастеркова': 6,
#  'Автозаводская улица': 38,
#  'Битцевский проезд': 12,
#  'Коломенская набережная': 22,
#  'улица Симоновский Вал': 20,
#  'улица Большие Каменщики': 12,
#  'Затонная улица': 10,
#  'Якорная улица': 10,
#  'улица Трофимова': 30,
#  'улица Газопровод': 12,
#  'Бойцовая улица': 16,
#  '4-я Гражданская улица': 4,
#  'улица Богородский Вал': 4,
#  'Потешная улица': 8,
#  'Русаковская набережная': 2,
#  '1-я Рыбинская улица': 2,
#  'Водопроводный переулок': 4,
#  'Преображенская улица': 8,
#  'проспект Будённого': 70,
#  'улица Бориса Жигулёнкова': 8,
#  '8-я улица Соколиной Горы': 4,
#  'Сиреневый бульвар': 38,
#  'Щёлковский проезд': 2,
#  'Щёлковское шоссе': 92,
#  'Преображенская площадь': 4,
#  'Вербная улица': 4,
#  'шоссе Энтузиастов': 172,
#  '2-й Полевой переулок': 6,
#  'Котляковская улица': 10,
#  '2-й Котляковский переулок': 6,
#  '1-й Варшавский проезд': 4,
#  'Каширский проезд': 2,
#  'Хабаровская улица': 36,
#  'улица Гастелло': 16,
#  '15-я Парковая улица': 24,
#  'улица Шумкина': 8,
#  'Старая Басманная улица': 14,
#  'улица Земляной Вал': 30,
#  'Костомаровский переулок': 12,
#  'улица Сергия Радонежского': 10,
#  'Новорогожская улица': 10,
#  'Севастопольский проспект': 90,
#  'Азовская улица': 16,
#  'Коломенское шоссе': 4,
#  'улица Садовники': 4,
#  'Коломенский проезд': 18,
#  'улица Академика Миллионщикова': 22,
#  'Донская улица': 2,
#  'Зелёный проспект': 90,
#  '3-я Владимирская улица': 20,
#  '3-я Рыбинская улица': 4,
#  'Рабочая улица': 14,
#  'улица Лобачика': 4,
#  'Камчатская улица': 10,
#  'Сахалинская улица': 2,
#  'Уральская улица': 26,
#  '9-я Парковая улица': 26,
#  'Курганская улица': 8,
#  'Уссурийская улица': 12,
#  'Измайловский бульвар': 32,
#  '3-я Парковая улица': 24,
#  'улица Радио': 20,
#  'Бауманская улица': 34,
#  'Протопоповский переулок': 18,
#  'Делегатская улица': 2,
#  '3-й Самотёчный переулок': 10,
#  'улица Достоевского': 6,
#  'Ольховская улица': 4,
#  'Красноказарменная улица': 38,
#  'Байкальская улица': 30,
#  'Чусовская улица': 8,
#  'Иркутская улица': 6,
#  '2-й Иртышский проезд': 10,
#  'улица Бирюсинка': 14,
#  'Амурская улица': 14,
#  'Одесская улица': 8,
#  'улица Дмитрия Ульянова': 32,
#  'Нагорная улица': 30,
#  'Красноярская улица': 12,
#  'Алтайская улица': 26,
#  'Спартаковская площадь': 2,
#  'улица Молостовых': 24,
#  'Свободный проспект': 52,
#  'Вешняковская улица': 44,
#  'улица Красный Казанец': 42,
#  'Саянская улица': 18,
#  'улица Сталеваров': 32,
#  'улица Старый Гай': 8,
#  'Кетчерская улица': 20,
#  'Напольный проезд': 8,
#  'Снайперская улица': 6,
#  'улица Молдагуловой': 24,
#  'Фрязевская улица': 12,
#  'Мартеновская улица': 12,
#  'Новогиреевская улица': 26,
#  'Перовская улица': 44,
#  'Кусковская улица': 20,
#  'улица Плющева': 12,
#  'Электродная улица': 10,
#  'улица Уткина': 6,
#  'Окружной проезд': 30,
#  'Вольная улица': 12,
#  'Федеративный проспект': 28,
#  'улица Металлургов': 10,
#  '2-я Владимирская улица': 22,
#  'улица Плеханова': 28,
#  'улица Аносова': 2,
#  'Кусковский тупик': 2,
#  'улица Лазо': 10,
#  'Московский проспект': 22,
#  'Ломоносовский проспект': 78,
#  '1-я Владимирская улица': 20,
#  'Челябинская улица': 14,
#  'Большой Купавенский проезд': 14,
#  'Малый Купавенский проезд': 4,
#  '16-я Парковая улица': 16,
#  '106-й километр Московской Кольцевой Автодороги': 4,
#  '108-й километр Московской Кольцевой Автодороги': 4,
#  'улица Юности': 36,
#  'улица Паперника': 6,
#  'Рязанский проспект': 82,
#  'Монтажная улица': 16,
#  'Открытое шоссе': 62,
#  'Измайловское шоссе': 12,
#  'улица Чечулина': 16,
#  'Реутовская улица': 20,
#  'аллея Жемчуговой': 12,
#  'улица Академика Скрябина': 24,
#  'Электролитный проезд': 12,
#  'улица Ремизова': 10,
#  'проезд Карамзина': 26,
#  'Голубинская улица': 40,
#  'Ясногорская улица': 8,
#  'улица Айвазовского': 8,
#  'улица Островитянова': 48,
#  'Тарусская улица': 12,
#  '5-я улица Соколиной Горы': 4,
#  'Яснополянская улица': 4,
#  'улица Михайлова': 22,
#  'улица Коновалова': 8,
#  'Кузьминская улица': 8,
#  'улица Миклухо-Маклая': 44,
#  'улица Введенского': 28,
#  'Нижегородская улица': 32,
#  'Таганская улица': 12,
#  'Оршанская улица': 4,
#  'улица Маршала Тимошенко': 12,
#  'Кунцевская улица': 4,
#  'Полоцкая улица': 6,
#  'улица Ивана Франко': 18,
#  'улица Василия Ботылёва': 10,
#  'Обводное шоссе': 6,
#  'улица Академика Павлова': 16,
#  'Новоясеневский проспект': 66,
#  'Литовский бульвар': 28,
#  '2-я Мякининская улица': 6,
#  'Бобруйская улица': 10,
#  'улица Екатерины Будановой': 4,
#  'улица Коцюбинского': 4,
#  'Никитский бульвар': 4,
#  '1-й Поперечный проезд': 8,
#  'Раушская набережная': 2,
#  'Космодамианская набережная': 6,
#  'улица Зацепский Вал': 8,
#  'Садовническая улица': 12,
#  'Болотная улица': 2,
#  'улица Новый Арбат': 18,
#  '2-я улица Машиностроения': 22,
#  '1-я улица Машиностроения': 12,
#  'улица Вострухина': 10,
#  'Сормовская улица': 8,
#  '7-я Парковая улица': 10,
#  '5-я Парковая улица': 14,
#  'Зубовская улица': 4,
#  'улица Пречистенка': 16,
#  'Гоголевский бульвар': 12,
#  'улица Юных Ленинцев': 46,
#  'Таганская площадь': 6,
#  'Верхняя Радищевская улица': 6,
#  'Яузская улица': 8,
#  'Москворецкая набережная': 12,
#  'Кремлёвская набережная': 4,
#  'Пречистенская набережная': 4,
#  'Подгорская набережная': 2,
#  'Нижняя Радищевская улица': 4,
#  'улица Александра Солженицына': 6,
#  'Николоямская улица': 20,
#  'Андроньевский проезд': 4,
#  'Волочаевская улица': 26,
#  'Душинская улица': 4,
#  'Главная улица': 2,
#  'Воронцовская улица': 12,
#  '1-я Дубровская улица': 16,
#  'Шарикоподшипниковская улица': 26,
#  '1-й Сетуньский проезд': 4,
#  '4-й Сетуньский проезд': 2,
#  '2-й Сетуньский проезд': 4,
#  'площадь Киевского Вокзала': 24,
#  'улица Покровка': 16,
#  'улица Маросейка': 4,
#  'Авиамоторная улица': 46,
#  '2-я Кабельная улица': 2,
#  '2-й Кабельный проезд': 2,
#  'Славянская площадь': 12,
#  'Новочерёмушкинская улица': 34,
#  'проезд Стройкомбината': 8,
#  'Очаковское шоссе': 12,
#  'Матвеевская улица': 16,
#  'Веерная улица': 20,
#  'Нежинская улица': 18,
#  'Староволынская улица': 12,
#  'проспект Вернадского': 126,
#  'Красноармейская улица': 14,
#  'Тверской бульвар': 12,
#  'улица Гарибальди': 20,
#  'улица Архитектора Власова': 18,
#  'Комсомольский проспект': 46,
#  'улица Остоженка': 12,
#  'Подольская улица': 12,
#  'улица Перерва': 56,
#  'улица Нижние Поля': 16,
#  'Волжский бульвар': 44,
#  'Саратовская улица': 12,
#  'улица Лобачевского': 46,
#  'Керченская улица': 8,
#  'Окская улица': 16,
#  'улица Фёдора Полетаева': 16,
#  'Жигулёвская улица': 6,
#  'улица Шкулёва': 8,
#  'Университетский проспект': 28,
#  'Семёновский проезд': 16,
#  'улица Семёновский Вал': 4,
#  'Доброслободская улица': 12,
#  'Новая Басманная улица': 14,
#  'Красноворотский проезд': 2,
#  'Белореченская улица': 30,
#  'Краснодарская улица': 44,
#  'улица Полбина': 30,
#  'Шоссейная улица': 82,
#  'улица Гурьянова': 32,
#  'Перовское шоссе': 20,
#  'шоссе Фрезер': 22,
#  '5-я Кабельная улица': 14,
#  'Новочеркасский бульвар': 28,
#  'Донецкая улица': 16,
#  'улица Олеко Дундича': 4,
#  'улица Маршала Голованова': 16,
#  'улица Горбунова': 14,
#  'улица Судакова': 10,
#  'Краснодонская улица': 38,
#  'Южнопортовая улица': 40,
#  'улица Коштоянца': 14,
#  'улица Удальцова': 38,
#  'Багратионовский проезд': 8,
#  'улица Полосухина': 2,
#  'Батайский проезд': 26,
#  'Ставропольская улица': 44,
#  '13-я Парковая улица': 6,
#  'Измайловская площадь': 4,
#  'Измайловский проезд': 4,
#  'Никитинская улица': 12,
#  '3-я Прядильная улица': 2,
#  '1-я Парковая улица': 4,
#  'Тихорецкий бульвар': 10,
#  'улица Рогожский Вал': 10,
#  'Абельмановская улица': 6,
#  '3-й Крутицкий переулок': 16,
#  'Солдатская улица': 6,
#  'Угрешская улица': 22,
#  'Большая Андроньевская улица': 8,
#  'Зеленодольский проезд': 4,
#  'улица Академика Волгина': 18,
#  'проспект 60-летия Октября': 22,
#  'Безымянный проезд': 4,
#  'Садовая-Черногрязская улица': 6,
#  'Лермонтовская площадь': 4,
#  'Садовая-Спасская улица': 8,
#  'Малая Сухаревская площадь': 6,
#  'Самотёчная площадь': 4,
#  'Садовая-Самотёчная улица': 8,
#  'Большая Садовая улица': 4,
#  'Садовая-Кудринская улица': 12,
#  'Зубовский бульвар': 8,
#  'улица Крымский Вал': 6,
#  'Валовая улица': 6,
#  'Большой Краснохолмский мост': 4,
#  'улица Пржевальского': 8,
#  'Большая Очаковская улица': 26,
#  'Никулинская улица': 10,
#  'Петровский бульвар': 6,
#  'Банный переулок': 4,
#  'Новосущёвский переулок': 8,
#  'Минаевский переулок': 4,
#  'улица Николая Химушина': 8,
#  'улица Академика Челомея': 6,
#  'улица Новаторов': 22,
#  'улица Воронцовские Пруды': 2,
#  'Вильнюсская улица': 8,
#  'Озёрная улица': 24,
#  'проектируемый проезд № 1980': 10,
#  'улица Бутлерова': 14,
#  'Мытная улица': 20,
#  'улица Шухова': 2,
#  'улица Академика Пилюгина': 22,
#  'улица Кравченко': 14,
#  'улица Воейкова': 4,
#  'улица Михаила Певцова': 4,
#  'улица Семёнова-Тян-Шанского': 4,
#  'Лубянская площадь': 10,
#  'Устьинская набережная': 2,
#  'улица Марии Ульяновой': 10,
#  'улица Академика Хохлова': 8,
#  'улица Лебедева': 10,
#  'улица Паустовского': 8,
#  'Борисовский проезд': 24,
#  'Смоленская улица': 4,
#  'проезд Нансена': 4,
#  'Грузинский переулок': 2,
#  'Ясеневая улица': 38,
#  'Фрунзенская набережная': 28,
#  'Сущёвская улица': 10,
#  'Нововоротниковский переулок': 2,
#  'Большая Грузинская улица': 16,
#  'Малая Грузинская улица': 12,
#  'Конюшковская улица': 8,
#  'улица Барышиха': 40,
#  'улица Борисовские Пруды': 50,
#  'Малая Андроньевская улица': 4,
#  'Братеевская улица': 24,
#  'Хордовый проезд': 10,
#  'Паромная улица': 10,
#  'Дубининская улица': 28,
#  'Холодильный переулок': 12,
#  'улица Даниловский Вал': 8,
#  'Елецкая улица': 10,
#  'площадь Крестьянская Застава': 4,
#  'Воронежская улица': 26,
#  'Сокольническая площадь': 4,
#  'Остаповский проезд': 4,
#  'Иловайская улица': 12,
#  'Софийская набережная': 2,
#  'Верхняя Красносельская улица': 18,
#  'Липецкая улица': 50,
#  'Бакинская улица': 20,
#  'улица Москворечье': 20,
#  'Промышленная улица': 16,
#  'Деловая улица': 4,
#  'улица Кошкина': 6,
#  'Кантемировская улица': 26,
#  'улица Бехтерева': 22,
#  'Севанская улица': 16,
#  'Ряжская улица': 8,
#  'Бирюлёвская улица': 24,
#  'Касимовская улица': 10,
#  'Лебедянская улица': 30,
#  'Загорьевская улица': 10,
#  'Михневская улица': 16,
#  'улица Серпуховский Вал': 20,
#  'Загорьевский проезд': 16,
#  'Каспийская улица': 38,
#  'улица Медиков': 12,
#  'Шипиловская улица': 32,
#  'Шипиловский проезд': 44,
#  'Домодедовская улица': 26,
#  'Ореховый бульвар': 56,
#  'улица Маршала Захарова': 16,
#  'Элеваторная улица': 2,
#  'Товарищеская улица': 2,
#  'Новоспасский проезд': 8,
#  'Новохохловская улица': 14,
#  'Луганская улица': 8,
#  'Новоостаповская улица': 14,
#  'Полимерная улица': 4,
#  '3-й Павелецкий проезд': 12,
#  'Павелецкая набережная': 6,
#  'Дербеневская набережная': 12,
#  'Кожевническая улица': 18,
#  'Носовихинское шоссе': 12,
#  'Городецкая улица': 16,
#  'Новокосинская улица': 28,
#  'Салтыковская улица': 48,
#  'улица Улофа Пальме': 2,
#  'улица Довженко': 12,
#  'улица Винокурова': 14,
#  'улица Шверника': 8,
#  'улица Гримау': 8,
#  'Менделеевская улица': 6,
#  'улица Богатырский Мост': 6,
#  'Елоховская площадь': 2,
#  '1-й Дербеневский переулок': 4,
#  'улица Маршала Чуйкова': 12,
#  'Михневский проезд': 8,
#  'Никольско-Архангельский проезд': 6,
#  '2-й километр Московской Кольцевой Автодороги': 4,
#  '3-й километр Московской Кольцевой Автодороги': 4,
#  'Задонский проезд': 26,
#  'улица Мусы Джалиля': 30,
#  'Ореховый проезд': 10,
#  'улица Генерала Белова': 30,
#  'Кустанайская улица': 10,
#  'Гурьевский проезд': 16,
#  'Тамбовская улица': 4,
#  'Зеленодольская улица': 8,
#  'улица Маршала Шестопалова': 20,
#  'улица Павла Андреева': 2,
#  'Ключевая улица': 22,
#  'Нижняя Краснохолмская улица': 2,
#  'Даниловская набережная': 8,
#  'Алма-Атинская улица': 4,
#  'улица Галины Вишневской': 2,
#  'Суздальская улица': 36,
#  'улица Строителей': 10,
#  'Юрьевский переулок': 8,
#  'Ухтомская улица': 10,
#  'Нагорный проезд': 12,
#  'улица Шаболовка': 22,
#  'улица Кржижановского': 30,
#  'Большая Черёмушкинская улица': 38,
#  'Загородное шоссе': 26,
#  'улица Вавилова': 46,
#  'улица Орджоникидзе': 8,
#  'Новокузнецкая улица': 12,
#  'Садовнический проезд': 8,
#  'Устьинский проезд': 8,
#  'Яузский бульвар': 2,
#  'Хохловская площадь': 2,
#  'Чистопрудный бульвар': 8,
#  'Покровский бульвар': 6,
#  'Лосиноостровская улица': 32,
#  'Пермская улица': 12,
#  '6-й Лучевой просек': 6,
#  'Белокаменное шоссе': 4,
#  'Яузская аллея': 16,
#  '6-я Радиальная улица': 14,
#  'Пятницкая улица': 10,
#  'улица Большая Ордынка': 12,
#  'Большой Москворецкий мост': 6,
#  '2-й Боткинский проезд': 6,
#  '1-й Боткинский проезд': 4,
#  'улица Матросская Тишина': 18,
#  'Большая Почтовая улица': 16,
#  'Малая Почтовая улица': 6,
#  '1-й Капотнинский проезд': 14,
#  'улица Верхние Поля': 56,
#  'Чагинская улица': 12,
#  'улица Капотня': 28,
#  '14-й километр Московской Кольцевой Автодороги': 4,
#  '11-й километр Московской Кольцевой Автодороги': 6,
#  'улица Цюрупы': 16,
#  'улица Крупской': 8,
#  '4-й Загородный проезд': 10,
#  'Кубанская улица': 2,
#  'Курская улица': 2,
#  '7-я улица Текстильщиков': 2,
#  'Новоцарицынское шоссе': 14,
#  '1-я Радиальная улица': 2,
#  '3-я Радиальная улица': 8,
#  '40-й километр Московской Кольцевой Автодороги': 4,
#  '38-й километр Московской Кольцевой Автодороги': 4,
#  '37-й километр Московской Кольцевой Автодороги': 4,
#  '35-й километр Московской Кольцевой Автодороги': 4,
#  '34-й километр Московской Кольцевой Автодороги': 8,
#  '33-й километр Московской Кольцевой Автодороги': 4,
#  '32-й километр Московской Кольцевой Автодороги': 8,
#  '31-й километр Московской Кольцевой Автодороги': 4,
#  '29-й километр Московской Кольцевой Автодороги': 4,
#  '27-й километр Московской Кольцевой Автодороги': 4,
#  '25-й километр Московской Кольцевой Автодороги': 2,
#  'Шелепихинский мост': 2,
#  '2-я Брестская улица': 4,
#  'улица Тёплый Стан': 28,
#  'проезд Одоевского': 8,
#  'Малая Тульская улица': 10,
#  'улица Раменки': 8,
#  'улица Кедрова': 8,
#  'улица Инессы Арманд': 10,
#  'Тропарёвская улица': 14,
#  '7-я Кожуховская улица': 8,
#  'улица Петра Романова': 2,
#  '6-я Кожуховская улица': 4,
#  'Новомарьинская улица': 24,
#  'улица Ивана Бабушкина': 4,
#  'Соймоновский проезд': 2,
#  'улица Академика Варги': 22,
#  'Рочдельская улица': 8,
#  'улица Генерала Тюленева': 16,
#  '3-я Никопольская улица': 2,
#  'Мелитопольская улица': 2,
#  'проезд Олимпийской Деревни': 6,
#  'улица Рокотова': 6,
#  'Соловьиный проезд': 12,
#  'Боровское шоссе': 130,
#  'Солнцевский проспект': 16,
#  'улица Богданова': 16,
#  '48-й километр Московской Кольцевой Автодороги': 6,
#  'улица Академика Анохина': 32,
#  'улица Академика Бакулева': 12,
#  'Санаторная аллея': 4,
#  'Теплостанский проезд': 2,
#  'Троекуровский проезд': 6,
#  'улица Тюрина': 2,
#  'Попутная улица': 14,
#  'улица 50 лет Октября': 16,
#  'Донбасская улица': 2,
#  'Верхняя Сыромятническая улица': 4,
#  'Гаврикова улица': 4,
#  'Марксистская улица': 20,
#  'бульвар Энтузиастов': 6,
#  'Инициативная улица': 10,
#  'Елизаветинский переулок': 8,
#  ...}

# %%
# %time
sorted(streets.items(), key=lambda item: item[1], reverse=True)
# Out:
# Wall time: 0 ns
# [('проезд без названия', 1514),
#  ('Варшавское шоссе', 380),
#  ('Калужское шоссе', 232),
#  ('шоссе Энтузиастов', 172),
#  ('Дмитровское шоссе', 152),
#  ('Ленинский проспект', 150),
#  ('проспект Мира', 148),
#  ('Чертановская улица', 134),
#  ('Боровское шоссе', 130),
#  ('проспект Вернадского', 126),
#  ('Ленинградское шоссе', 124),
#  ('Каширское шоссе', 122),
#  ('Профсоюзная улица', 114),
#  ('Волгоградский проспект', 106),
#  ('Волоколамское шоссе', 104),
#  ('Алтуфьевское шоссе', 98),
#  ('Щёлковское шоссе', 92),
#  ('Севастопольский проспект', 90),
#  ('Зелёный проспект', 90),
#  ('Центральная улица', 90),
#  ('Люблинская улица', 86),
#  ('Первомайская улица', 86),
#  ('Мичуринский проспект', 84),
#  ('Рублёвское шоссе', 82),
#  ('Рязанский проспект', 82),
#  ('Шоссейная улица', 82),
#  ('Ломоносовский проспект', 78),
#  ('Кутузовский проспект', 76),
#  ('Киевское шоссе', 76),
#  ('Ленинградский проспект', 74),
#  ('улица Героев Панфиловцев', 74),
#  ('улица Свободы', 72),
#  ('проспект Будённого', 70),
#  ('Привольная улица', 68),
#  ('Нахимовский проспект', 66),
#  ('Новоясеневский проспект', 66),
#  ('Фестивальная улица', 62),
#  ('Рябиновая улица', 62),
#  ('Открытое шоссе', 62),
#  ('Дубнинская улица', 60),
#  ('Судостроительная улица', 60),
#  ('Кировоградская улица', 58),
#  ('Ярославское шоссе', 56),
#  ('улица Перерва', 56),
#  ('Ореховый бульвар', 56),
#  ('улица Верхние Поля', 56),
#  ('проспект Андропова', 54),
#  ('Свободный проспект', 52),
#  ('улица Александры Монаховой', 52),
#  ('Большая Академическая улица', 50),
#  ('улица Народного Ополчения', 50),
#  ('Симферопольский бульвар', 50),
#  ('улица Борисовские Пруды', 50),
#  ('Липецкая улица', 50),
#  ('Коровинское шоссе', 48),
#  ('Полярная улица', 48),
#  ('Пролетарский проспект', 48),
#  ('Краснобогатырская улица', 48),
#  ('улица Островитянова', 48),
#  ('Салтыковская улица', 48),
#  ('Большой бульвар', 48),
#  ('Хорошёвское шоссе', 46),
#  ('Енисейская улица', 46),
#  ('Широкая улица', 46),
#  ('улица Юных Ленинцев', 46),
#  ('Авиамоторная улица', 46),
#  ('Комсомольский проспект', 46),
#  ('улица Лобачевского', 46),
#  ('улица Вавилова', 46),
#  ('Бескудниковский бульвар', 44),
#  ('Тимирязевская улица', 44),
#  ('Дорожная улица', 44),
#  ('Болотниковская улица', 44),
#  ('Вешняковская улица', 44),
#  ('Перовская улица', 44),
#  ('улица Миклухо-Маклая', 44),
#  ('Волжский бульвар', 44),
#  ('Краснодарская улица', 44),
#  ('Ставропольская улица', 44),
#  ('Шипиловский проезд', 44),
#  ('Панфиловский проспект', 44),
#  ('Кронштадтский бульвар', 42),
#  ('проспект Маршала Жукова', 42),
#  ('улица Красный Казанец', 42),
#  ('Пятницкое шоссе', 42),
#  ('улица Александра Печерского', 42),
#  ('Крылатская улица', 40),
#  ('Мосфильмовская улица', 40),
#  ('Балаклавский проспект', 40),
#  ('Большая Черкизовская улица', 40),
#  ('Голубинская улица', 40),
#  ('Южнопортовая улица', 40),
#  ('улица Барышиха', 40),
#  ('Смольная улица', 38),
#  ('Продольный проезд', 38),
#  ('улица Красного Маяка', 38),
#  ('улица Обручева', 38),
#  ('Автозаводская улица', 38),
#  ('Сиреневый бульвар', 38),
#  ('Красноказарменная улица', 38),
#  ('Краснодонская улица', 38),
#  ('улица Удальцова', 38),
#  ('Ясеневая улица', 38),
#  ('Каспийская улица', 38),
#  ('Большая Черёмушкинская улица', 38),
#  ('Чечёрский проезд', 38),
#  ('бульвар Яна Райниса', 36),
#  ('улица Лескова', 36),
#  ('Таллинская улица', 36),
#  ('улица Барклая', 36),
#  ('улица Менжинского', 36),
#  ('Кастанаевская улица', 36),
#  ('Молодогвардейская улица', 36),
#  ('Сельскохозяйственная улица', 36),
#  ('улица Каховка', 36),
#  ('Хабаровская улица', 36),
#  ('улица Юности', 36),
#  ('Суздальская улица', 36),
#  ('Южнобутовская улица', 36),
#  ('Ангарская улица', 34),
#  ('улица Академика Королёва', 34),
#  ('Сходненская улица', 34),
#  ('улица Кулакова', 34),
#  ('улица Крылатские Холмы', 34),
#  ('Можайское шоссе', 34),
#  ('улица Лётчика Бабушкина', 34),
#  ('улица Подольских Курсантов', 34),
#  ('Нагатинская набережная', 34),
#  ('улица Хлобыстова', 34),
#  ('Бауманская улица', 34),
#  ('Новочерёмушкинская улица', 34),
#  ('Новокуркинское шоссе', 34),
#  ('Новосходненское шоссе', 34),
#  ('улица Сущёвский Вал', 32),
#  ('улица Маршала Бирюзова', 32),
#  ('улица Маршала Катукова', 32),
#  ('Живописная улица', 32),
#  ('Новощукинская улица', 32),
#  ('Большая Филёвская улица', 32),
#  ('Минская улица', 32),
#  ('Череповецкая улица', 32),
#  ('Аминьевское шоссе', 32),
#  ('Измайловский бульвар', 32),
#  ('улица Дмитрия Ульянова', 32),
#  ('улица Сталеваров', 32),
#  ('Нижегородская улица', 32),
#  ('улица Гурьянова', 32),
#  ('Шипиловская улица', 32),
#  ('Лосиноостровская улица', 32),
#  ('улица Академика Анохина', 32),
#  ('улица Генерала Белобородова', 30),
#  ('улица Корнейчука', 30),
#  ('улица Декабристов', 30),
#  ('Нагатинская улица', 30),
#  ('Поперечный просек', 30),
#  ('Ивантеевская улица', 30),
#  ('улица Трофимова', 30),
#  ('улица Земляной Вал', 30),
#  ('Байкальская улица', 30),
#  ('Нагорная улица', 30),
#  ('Окружной проезд', 30),
#  ('Белореченская улица', 30),
#  ('улица Полбина', 30),
#  ('Лебедянская улица', 30),
#  ('улица Мусы Джалиля', 30),
#  ('улица Генерала Белова', 30),
#  ('улица Кржижановского', 30),
#  ('улица Авиаторов', 30),
#  ('улица Адмирала Корнилова', 30),
#  ('улица Марьинский Парк', 30),
#  ('Саларьевская улица', 30),
#  ('улица Зои и Александра Космодемьянских', 28),
#  ('Михалковская улица', 28),
#  ('Митинская улица', 28),
#  ('Бутырская улица', 28),
#  ('Ботаническая улица', 28),
#  ('Авиационная улица', 28),
#  ('улица Исаковского', 28),
#  ('Таманская улица', 28),
#  ('Планерная улица', 28),
#  ('улица Косыгина', 28),
#  ('Днепропетровская улица', 28),
#  ('Шмитовский проезд', 28),
#  ('Кавказский бульвар', 28),
#  ('улица Стромынка', 28),
#  ('Федеративный проспект', 28),
#  ('улица Плеханова', 28),
#  ('улица Введенского', 28),
#  ('Литовский бульвар', 28),
#  ('Университетский проспект', 28),
#  ('Новочеркасский бульвар', 28),
#  ('Фрунзенская набережная', 28),
#  ('Дубининская улица', 28),
#  ('Новокосинская улица', 28),
#  ('улица Капотня', 28),
#  ('улица Тёплый Стан', 28),
#  ('бульвар Дмитрия Донского', 28),
#  ('Поречная улица', 28),
#  ('2-я Вольская улица', 28),
#  ('улица Адмирала Лазарева', 28),
#  ('Заводская улица', 28),
#  ('проспект Генерала Алексеева', 28),
#  ('улица 800-летия Москвы', 26),
#  ('улица Дыбенко', 26),
#  ('Флотская улица', 26),
#  ('Лодочная улица', 26),
#  ('улица Бориса Галушкина', 26),
#  ('Сколковское шоссе', 26),
#  ('проезд Дежнёва', 26),
#  ('Шереметьевская улица', 26),
#  ('Востряковский проезд', 26),
#  ('Ташкентская улица', 26),
#  ('Уральская улица', 26),
#  ('9-я Парковая улица', 26),
#  ('Алтайская улица', 26),
#  ('Новогиреевская улица', 26),
#  ('проезд Карамзина', 26),
#  ('Волочаевская улица', 26),
#  ('Шарикоподшипниковская улица', 26),
#  ('Батайский проезд', 26),
#  ('Большая Очаковская улица', 26),
#  ('Воронежская улица', 26),
#  ('Кантемировская улица', 26),
#  ('Домодедовская улица', 26),
#  ('Задонский проезд', 26),
#  ('Загородное шоссе', 26),
#  ('Дубравная улица', 26),
#  ('Большая Косинская улица', 26),
#  ('Лухмановская улица', 26),
#  ('Железнодорожная улица', 26),
#  ('Клязьминская улица', 24),
#  ('Коптевская улица', 24),
#  ('Зеленоградская улица', 24),
#  ('Большая Пироговская улица', 24),
#  ('улица Берзарина', 24),
#  ('Street', 24),
#  ('Барвихинская улица', 24),
#  ('Малая Филёвская улица', 24),
#  ('Абрамцевская улица', 24),
#  ('Беловежская улица', 24),
#  ('Стартовая улица', 24),
#  ('проезд Шокальского', 24),
#  ('улица Грекова', 24),
#  ('Новозаводская улица', 24),
#  ('Ясный проезд', 24),
#  ('улица Хачатуряна', 24),
#  ('1-я Останкинская улица', 24),
#  ('Чонгарский бульвар', 24),
#  ('Огородный проезд', 24),
#  ('Булатниковский проезд', 24),
#  ('Трифоновская улица', 24),
#  ('Русаковская улица', 24),
#  ('Электрозаводская улица', 24),
#  ('улица Сокольнический Вал', 24),
#  ('15-я Парковая улица', 24),
#  ('3-я Парковая улица', 24),
#  ('улица Молостовых', 24),
#  ('улица Молдагуловой', 24),
#  ('улица Академика Скрябина', 24),
#  ('площадь Киевского Вокзала', 24),
#  ('Озёрная улица', 24),
#  ('Борисовский проезд', 24),
#  ('Братеевская улица', 24),
#  ('Бирюлёвская улица', 24),
#  ('Новомарьинская улица', 24),
#  ('Мячковский бульвар', 24),
#  ('Родниковая улица', 24),
#  ('Центральный проспект', 24),
#  ('улица Ленина', 24),
#  ('улица Андреевка', 24),
#  ('Лесная улица', 24),
#  ('Октябрьский проспект', 24),
#  ('Онежская улица', 22),
#  ('улица Василия Петушкова', 22),
#  ('улица Куусинена', 22),
#  ('улица Маршала Тухачевского', 22),
#  ('улица Коминтерна', 22),
#  ('проезд Серебрякова', 22),
#  ('Туристская улица', 22),
#  ('улица Твардовского', 22),
#  ('Тушинская площадь', 22),
#  ('Бибиревская улица', 22),
#  ('Большая Дорогомиловская улица', 22),
#  ('Юрловский проезд', 22),
#  ('Партизанская улица', 22),
#  ('улица Яблочкова', 22),
#  ('Медынская улица', 22),
#  ('Коломенская улица', 22),
#  ('Самаркандский бульвар', 22),
#  ('Бакунинская улица', 22),
#  ('Коломенская набережная', 22),
#  ('улица Академика Миллионщикова', 22),
#  ('2-я Владимирская улица', 22),
#  ('Московский проспект', 22),
#  ('улица Михайлова', 22),
#  ('2-я улица Машиностроения', 22),
#  ('шоссе Фрезер', 22),
#  ('Угрешская улица', 22),
#  ('проспект 60-летия Октября', 22),
#  ('улица Новаторов', 22),
#  ('улица Академика Пилюгина', 22),
#  ('улица Бехтерева', 22),
#  ('Ключевая улица', 22),
#  ('улица Шаболовка', 22),
#  ('улица Академика Варги', 22),
#  ('улица Генерала Дорохова', 22),
#  ('Бартеневская улица', 22),
#  ('Советская улица', 22),
#  ('Солнечная улица', 22),
#  ('улица Каменка', 22),
#  ('Сосновая аллея', 22),
#  ('улица Брусилова', 22),
#  ('Покровская улица', 22),
#  ('2-й Лихачёвский переулок', 22),
#  ('Старопетровский проезд', 20),
#  ('Херсонская улица', 20),
#  ('Карамышевская набережная', 20),
#  ('Звенигородское шоссе', 20),
#  ('Анадырский проезд', 20),
#  ('Изумрудная улица', 20),
#  ('Радужная улица', 20),
#  ('улица Фабрициуса', 20),
#  ('Снежная улица', 20),
#  ('улица Вилиса Лациса', 20),
#  ('Осенний бульвар', 20),
#  ('3-я Хорошёвская улица', 20),
#  ('Осташковская улица', 20),
#  ('Верейская улица', 20),
#  ('3-й Дорожный проезд', 20),
#  ('улица Милашенкова', 20),
#  ('улица Симоновский Вал', 20),
#  ('3-я Владимирская улица', 20),
#  ('улица Радио', 20),
#  ('Кетчерская улица', 20),
#  ('Кусковская улица', 20),
#  ('1-я Владимирская улица', 20),
#  ('Реутовская улица', 20),
#  ('Николоямская улица', 20),
#  ('Веерная улица', 20),
#  ('улица Гарибальди', 20),
#  ('Перовское шоссе', 20),
#  ('Мытная улица', 20),
#  ('Бакинская улица', 20),
#  ('улица Москворечье', 20),
#  ('улица Серпуховский Вал', 20),
#  ('улица Маршала Шестопалова', 20),
#  ('Марксистская улица', 20),
#  ('Совхозная улица', 20),
#  ('улица 8 Марта', 20),
#  ('Старобитцевская улица', 20),
#  ('улица Маршала Полубоярова', 20),
#  ('улица Генерала Кузнецова', 20),
#  ('Венёвская улица', 20),
#  ('улица Поляны', 20),
#  ('Куркинское шоссе', 20),
#  ('Братиславская улица', 20),
#  ('улица Бунинская Аллея', 20),
#  ('Георгиевский проспект', 20),
#  ('Машкинское шоссе', 20),
#  ('Рязановское шоссе', 20),
#  ('Староникольская улица', 20),
#  ('Петрозаводская улица', 18),
#  ('Беломорская улица', 18),
#  ('улица Красная Пресня', 18),
#  ('улица Мнёвники', 18),
#  ('улица Малыгина', 18),
#  ('Строгинский бульвар', 18),
#  ('улица Софьи Ковалевской', 18),
#  ('улица Нижние Мнёвники', 18),
#  ('Берёзовая аллея', 18),
#  ('Сигнальный проезд', 18),
#  ('улица Пришвина', 18),
#  ('улица Красных Зорь', 18),
#  ('Бережковская набережная', 18),
#  ('Филёвский бульвар', 18),
#  ('улица 26-ти Бакинских Комиссаров', 18),
#  ('улица Римского-Корсакова', 18),
#  ('Булатниковская улица', 18),
#  ('Большая Серпуховская улица', 18),
#  ('Ереванская улица', 18),
#  ('Каланчёвская улица', 18),
#  ('Ферганский проезд', 18),
#  ('Ферганская улица', 18),
#  ('Черноморский бульвар', 18),
#  ('Измайловский проспект', 18),
#  ('Коломенский проезд', 18),
#  ('Протопоповский переулок', 18),
#  ('Саянская улица', 18),
#  ('улица Ивана Франко', 18),
#  ('улица Новый Арбат', 18),
#  ('Нежинская улица', 18),
#  ('улица Архитектора Власова', 18),
#  ('улица Академика Волгина', 18),
#  ('Верхняя Красносельская улица', 18),
#  ('Кожевническая улица', 18),
#  ('улица Матросская Тишина', 18),
#  ('улица Шолохова', 18),
#  ('улица Скульптора Мухиной', 18),
#  ('Лукинская улица', 18),
#  ('улица Николая Старостина', 18),
#  ('улица Верхняя Масловка', 18),
#  ('улица Горчакова', 18),
#  ('Перервинский бульвар', 18),
#  ('Харьковский проезд', 18),
#  ('Ярославская улица', 18),
#  ('Воротынская улица', 18),
#  ('улица Руднёвка', 18),
#  ('Большая Никитская улица', 18),
#  ('улица Лётчика Спирина', 18),
#  ('Муравская улица', 18),
#  ('Косинская улица', 18),
#  ('Внуковское шоссе', 18),
#  ('Косинское шоссе', 18),
#  ('Рождественская улица', 18),
#  ('проспект 40 лет Октября', 18),
#  ('улица Генерала Донскова', 18),
#  ('Соболевский проезд', 18),
#  ('улица Госпитальный Вал', 18),
#  ('Тверская улица', 18),
#  ('Локомотивный проезд', 16),
#  ('Петровско-Разумовский проезд', 16),
#  ('улица Бутырский Вал', 16),
#  ('Новослободская улица', 16),
#  ('улица Плющиха', 16),
#  ('Башиловская улица', 16),
#  ('улица Нижняя Масловка', 16),
#  ('улица Костякова', 16),
#  ('улица Константина Царёва', 16),
#  ('Новопесчаная улица', 16),
#  ('проезд Донелайтиса', 16),
#  ('улица Маршала Василевского', 16),
#  ('Ельнинская улица', 16),
#  ('Богородское шоссе', 16),
#  ('Прибрежный проезд', 16),
#  ('Неманский проезд', 16),
#  ('1-й Силикатный проезд', 16),
#  ('Костромская улица', 16),
#  ('Осенняя улица', 16),
#  ('улица Плещеева', 16),
#  ('Ярцевская улица', 16),
#  ('Давыдковская улица', 16),
#  ('Студёный проезд', 16),
#  ('улица Молодцова', 16),
#  ('Северный бульвар', 16),
#  ('Путевой проезд', 16),
#  ('улица Руставели', 16),
#  ('улица Пресненский Вал', 16),
#  ('улица Большая Полянка', 16),
#  ('Люсиновская улица', 16),
#  ('Олимпийский проспект', 16),
#  ('Малахитовая улица', 16),
#  ('2-й Грайвороновский проезд', 16),
#  ('улица Павла Корчагина', 16),
#  ('улица Измайловский Вал', 16),
#  ('Щербаковская улица', 16),
#  ('Ткацкая улица', 16),
#  ('Халтуринская улица', 16),
#  ('Бойцовая улица', 16),
#  ('улица Гастелло', 16),
#  ('Азовская улица', 16),
#  ('16-я Парковая улица', 16),
#  ('Монтажная улица', 16),
#  ('улица Чечулина', 16),
#  ('улица Академика Павлова', 16),
#  ('улица Пречистенка', 16),
#  ('1-я Дубровская улица', 16),
#  ('улица Покровка', 16),
#  ('Матвеевская улица', 16),
#  ('улица Нижние Поля', 16),
#  ('Окская улица', 16),
#  ('улица Фёдора Полетаева', 16),
#  ('Семёновский проезд', 16),
#  ('Донецкая улица', 16),
#  ('улица Маршала Голованова', 16),
#  ('3-й Крутицкий переулок', 16),
#  ('Большая Грузинская улица', 16),
#  ('Промышленная улица', 16),
#  ('Севанская улица', 16),
#  ('Михневская улица', 16),
#  ('Загорьевский проезд', 16),
#  ('улица Маршала Захарова', 16),
#  ('Городецкая улица', 16),
#  ('Гурьевский проезд', 16),
#  ('Яузская аллея', 16),
#  ('Большая Почтовая улица', 16),
#  ('улица Цюрупы', 16),
#  ('улица Генерала Тюленева', 16),
#  ('Солнцевский проспект', 16),
#  ('улица Богданова', 16),
#  ('улица 50 лет Октября', 16),
#  ('улица Грина', 16),
#  ('Скобелевская улица', 16),
#  ('Приречная улица', 16),
#  ('улица Авиаконструктора Миля', 16),
#  ('Изюмская улица', 16),
#  ('улица Академика Семёнова', 16),
#  ('Нижняя Красносельская улица', 16),
#  ('Никольский проезд', 16),
#  ('Крюковская площадь', 16),
#  ('Фирсановское шоссе', 16),
#  ('улица Авиаконструктора Сухого', 16),
#  ('улица Маршала Савицкого', 16),
#  ('Московская улица', 16),
#  ('Мещерский проспект', 16),
#  ('Колхозная улица', 16),
#  ('Большая Калитниковская улица', 16),
#  ('Краснопресненская набережная', 16),
#  ('Планетная улица', 14),
#  ('Новомосковская улица', 14),
#  ('Походный проезд', 14),
#  ('улица Алабяна', 14),
#  ('Лобненская улица', 14),
#  ('Карельский бульвар', 14),
#  ('улица Космонавта Волкова', 14),
#  ('Беговая улица', 14),
#  ('улица Заморёнова', 14),
#  ('Белозерская улица', 14),
#  ('улица Ивана Сусанина', 14),
#  ('улица Маршала Неделина', 14),
#  ('улица Конёнкова', 14),
#  ('Славянский бульвар', 14),
#  ('улица Бестужевых', 14),
#  ('Сумской проезд', 14),
#  ('Большая Тульская улица', 14),
#  ('улица Докукина', 14),
#  ('проезд Русанова', 14),
#  ('Грайвороновская улица', 14),
#  ('Большая Семёновская улица', 14),
#  ('Старая Басманная улица', 14),
#  ('Рабочая улица', 14),
#  ('улица Бирюсинка', 14),
#  ('Амурская улица', 14),
#  ('Челябинская улица', 14),
#  ('Большой Купавенский проезд', 14),
#  ('5-я Парковая улица', 14),
#  ('Красноармейская улица', 14),
#  ('Новая Басманная улица', 14),
#  ('5-я Кабельная улица', 14),
#  ('улица Горбунова', 14),
#  ('улица Коштоянца', 14),
#  ('улица Бутлерова', 14),
#  ('улица Кравченко', 14),
#  ('Новохохловская улица', 14),
#  ('Новоостаповская улица', 14),
#  ('улица Винокурова', 14),
#  ('6-я Радиальная улица', 14),
#  ('1-й Капотнинский проезд', 14),
#  ('Новоцарицынское шоссе', 14),
#  ('Тропарёвская улица', 14),
#  ('Попутная улица', 14),
#  ('Новороссийская улица', 14),
#  ('Куликовская улица', 14),
#  ('улица Федосьино', 14),
#  ('Боровская улица', 14),
#  ('Вятская улица', 14),
#  ('Соколово-Мещерская улица', 14),
#  ('Юровская улица', 14),
#  ('улица Логвиненко', 14),
#  ('Новокрюковская улица', 14),
#  ('Алабушевская улица', 14),
#  ('Святоозерская улица', 14),
#  ('улица Дмитриевского', 14),
#  ('улица Красная Сосна', 14),
#  ('улица Академика Флёрова', 14),
#  ('проспект Защитников Москвы', 14),
#  ('улица Адмирала Макарова', 14),
#  ('4-я линия Хорошёвского Серебряного Бора', 14),
#  ('улица Линии Октябрьской Железной Дороги', 12),
#  ('Нарвская улица', 12),
#  ('Автомоторная улица', 12),
#  ('Петровско-Разумовская аллея', 12),
#  ('Авангардная улица', 12),
#  ('Солнечногорская улица', 12),
#  ('улица Вучетича', 12),
#  ('Ижорская улица', 12),
#  ('улица Маршала Федоренко', 12),
#  ('улица Хамовнический Вал', 12),
#  ('Химкинский бульвар', 12),
#  ('улица Генерала Глаголева', 12),
#  ('Ростокинский проезд', 12),
#  ('Строгинское шоссе', 12),
#  ('улица Гамалеи', 12),
#  ('4-я Магистральная улица', 12),
#  ('Мурановская улица', 12),
#  ('Илимская улица', 12),
#  ('улица Говорова', 12),
#  ('Северодвинская улица', 12),
#  ('Тайнинская улица', 12),
#  ('Инженерная улица', 12),
#  ('Челюскинская улица', 12),
#  ('улица Академика Янгеля', 12),
#  ('Кольская улица', 12),
#  ('улица Советской Армии', 12),
#  ('Краснопролетарская улица', 12),
#  ('Долгоруковская улица', 12),
#  ('Стрельбищенский переулок', 12),
#  ('Новорязанская улица', 12),
#  ('Битцевский проезд', 12),
#  ('улица Большие Каменщики', 12),
#  ('улица Газопровод', 12),
#  ('Костомаровский переулок', 12),
#  ('Уссурийская улица', 12),
#  ('Красноярская улица', 12),
#  ('Фрязевская улица', 12),
#  ('Мартеновская улица', 12),
#  ('улица Плющева', 12),
#  ('Вольная улица', 12),
#  ('Измайловское шоссе', 12),
#  ('аллея Жемчуговой', 12),
#  ('Электролитный проезд', 12),
#  ('Тарусская улица', 12),
#  ('Таганская улица', 12),
#  ('улица Маршала Тимошенко', 12),
#  ('Садовническая улица', 12),
#  ('1-я улица Машиностроения', 12),
#  ('Гоголевский бульвар', 12),
#  ('Москворецкая набережная', 12),
#  ('Воронцовская улица', 12),
#  ('Славянская площадь', 12),
#  ('Очаковское шоссе', 12),
#  ('Староволынская улица', 12),
#  ('Тверской бульвар', 12),
#  ('улица Остоженка', 12),
#  ('Подольская улица', 12),
#  ('Саратовская улица', 12),
#  ('Доброслободская улица', 12),
#  ('Никитинская улица', 12),
#  ('Садовая-Кудринская улица', 12),
#  ('Малая Грузинская улица', 12),
#  ('Холодильный переулок', 12),
#  ('Иловайская улица', 12),
#  ('улица Медиков', 12),
#  ('3-й Павелецкий проезд', 12),
#  ('Дербеневская набережная', 12),
#  ('Носовихинское шоссе', 12),
#  ('улица Довженко', 12),
#  ('улица Маршала Чуйкова', 12),
#  ('Нагорный проезд', 12),
#  ('Новокузнецкая улица', 12),
#  ('Пермская улица', 12),
#  ('улица Большая Ордынка', 12),
#  ('Чагинская улица', 12),
#  ('Соловьиный проезд', 12),
#  ('улица Академика Бакулева', 12),
#  ('2-я Магистральная улица', 12),
#  ('Старокачаловская улица', 12),
#  ('Производственная улица', 12),
#  ('Коктебельская улица', 12),
#  ('Чоботовская улица', 12),
#  ('Златоустовская улица', 12),
#  ('Международное шоссе', 12),
#  ('улица Академика Комарова', 12),
#  ('Остафьевская улица', 12),
#  ('Заповедная улица', 12),
#  ('Большая Юшуньская улица', 12),
#  ('Левобережная улица', 12),
#  ('улица Маршала Воробьёва', 12),
#  ('улица Гризодубовой', 12),
#  ('Солнечная аллея', 12),
#  ('улица Гоголя', 12),
#  ('Филаретовская улица', 12),
#  ('Островная улица', 12),
#  ('Сухонская улица', 12),
#  ('Яковлевская улица', 12),
#  ('улица 40 лет Октября', 12),
#  ('Бачуринская улица', 12),
#  ('улица Золоторожский Вал', 12),
#  ('улица Пырьева', 12),
#  ('Автомобильный проезд', 12),
#  ('улица Зорге', 12),
#  ('Саввинская набережная', 12),
#  ('Новостроевская улица', 12),
#  ('Зимёнковская улица', 12),
#  ('Краснопрудная улица', 12),
#  ('улица Дубки', 12),
#  ('Погонный проезд', 12),
#  ('1-я Тверская-Ямская улица', 12),
#  ('Афанасовское шоссе', 12),
#  ('3-я Черепковская улица', 10),
#  ('улица Клары Цеткин', 10),
#  ('улица Прянишникова', 10),
#  ('Краснополянская улица', 10),
#  ('улица Лавочкина', 10),
#  ('Звёздный бульвар', 10),
#  ('Станционная улица', 10),
#  ('Красностуденческий проезд', 10),
#  ('улица Расплетина', 10),
#  ('2-я Квесисская улица', 10),
#  ('4-й Вятский переулок', 10),
#  ('улица Рогова', 10),
#  ('улица Маршала Новикова', 10),
#  ('3-я Магистральная улица', 10),
#  ('улица Вильгельма Пика', 10),
#  ('Олонецкая улица', 10),
#  ('2-й Хорошёвский проезд', 10),
#  ('Лианозовский проезд', 10),
#  ('улица Артамонова', 10),
#  ('Сумская улица', 10),
#  ('Вологодский проезд', 10),
#  ('улица Большая Якиманка', 10),
#  ('улица Мусоргского', 10),
#  ('Мирской переулок', 10),
#  ('улица Фонвизина', 10),
#  ('Печорская улица', 10),
#  ('улица Дурова', 10),
#  ('Ростокинская улица', 10),
#  ('улица Новинки', 10),
#  ('улица Преображенский Вал', 10),
#  ('Большая Оленья улица', 10),
#  ('Затонная улица', 10),
#  ('Якорная улица', 10),
#  ('Котляковская улица', 10),
#  ('улица Сергия Радонежского', 10),
#  ('Новорогожская улица', 10),
#  ('Камчатская улица', 10),
#  ('3-й Самотёчный переулок', 10),
#  ('2-й Иртышский проезд', 10),
#  ('Электродная улица', 10),
#  ('улица Металлургов', 10),
#  ('улица Лазо', 10),
#  ('улица Ремизова', 10),
#  ('улица Василия Ботылёва', 10),
#  ('Бобруйская улица', 10),
#  ('улица Вострухина', 10),
#  ('7-я Парковая улица', 10),
#  ('улица Судакова', 10),
#  ('Тихорецкий бульвар', 10),
#  ('улица Рогожский Вал', 10),
#  ('Никулинская улица', 10),
#  ('проектируемый проезд № 1980', 10),
#  ('Лубянская площадь', 10),
#  ('улица Марии Ульяновой', 10),
#  ('улица Лебедева', 10),
#  ('Сущёвская улица', 10),
#  ('Хордовый проезд', 10),
#  ('Паромная улица', 10),
#  ('Елецкая улица', 10),
#  ('Касимовская улица', 10),
#  ('Загорьевская улица', 10),
#  ('Ореховый проезд', 10),
#  ('Кустанайская улица', 10),
#  ('улица Строителей', 10),
#  ('Ухтомская улица', 10),
#  ('Пятницкая улица', 10),
#  ('4-й Загородный проезд', 10),
#  ('Малая Тульская улица', 10),
#  ('улица Инессы Арманд', 10),
#  ('Инициативная улица', 10),
#  ('Суворовская площадь', 10),
#  ('площадь Соловецких Юнг', 10),
#  ('улица Покрышкина', 10),
#  ('Домостроительная улица', 10),
#  ('Бесединское шоссе', 10),
#  ('улица Щорса', 10),
#  ('Новопеределкинская улица', 10),
#  ('Новоорловская улица', 10),
#  ('Луговой проезд', 10),
#  ('Красковская улица', 10),
#  ('1-я Вольская улица', 10),
#  ('Дмитровский проезд', 10),
#  ('Тихвинская улица', 10),
#  ('улица Проходчиков', 10),
#  ('улица Саморы Машела', 10),
#  ('улица Талалихина', 10),
#  ('улица Авиаконструктора Микояна', 10),
#  ('1-й Красногвардейский проезд', 10),
#  ('улица Михайловка', 10),
#  ('улица Конструктора Гуськова', 10),
#  ('улица Александровка', 10),
#  ('Малинская улица', 10),
#  ('Заводское шоссе', 10),
#  ('улица Лётчицы Тарасовой', 10),
#  ('улица Рословка', 10),
#  ('Вернисажная улица', 10),
#  ('Клинская улица', 10),
#  ('1-й Пенягинский проезд', 10),
#  ('улица Кибальчича', 10),
#  ('Раменский бульвар', 10),
#  ('Госпитальная улица', 10),
#  ('Набережная Новикова-Прибоя', 10),
#  ('улица Корнея Чуковского', 10),
#  ('Николо-Хованская улица', 10),
#  ('Улица Татьянин Парк', 10),
#  ('улица Ротерта', 10),
#  ('улица Вертолётчиков', 10),
#  ('Фитарёвская улица', 10),
#  ('Цветной бульвар', 10),
#  ('2-я Бауманская улица', 10),
#  ('площадь Савёловского вокзала', 10),
#  ('Коптевский бульвар', 8),
#  ('4-й Новомихалковский проезд', 8),
#  ('улица Академика Курчатова', 8),
#  ('1-й Волоколамский проезд', 8),
#  ('улица Усиевича', 8),
#  ('Часовая улица', 8),
#  ('2-я Хуторская улица', 8),
#  ('улица Бусиновская Горка', 8),
#  ('Новинский бульвар', 8),
#  ('улица 1905 Года', 8),
#  ('Смоленский бульвар', 8),
#  ('Светлогорский проезд', 8),
#  ('улица Расковой', 8),
#  ('3-й Нижнелихоборский проезд', 8),
#  ('Старый Петровско-Разумовский проезд', 8),
#  ('Строительный проезд', 8),
#  ('Песчаная улица', 8),
#  ('Талдомская улица', 8),
#  ('Керамический проезд', 8),
#  ('улица Паршина', 8),
#  ('проезд Стратонавтов', 8),
#  ('Одинцовская улица', 8),
#  ('Шелепихинское шоссе', 8),
#  ('Отрадная улица', 8),
#  ('Шелепихинская набережная', 8),
#  ('улица Фомичёвой', 8),
#  ('92-й километр Московской Кольцевой Автодороги', 8),
#  ('улица Толбухина', 8),
#  ('Кременчугская улица', 8),
#  ('Воробьёвское шоссе', 8),
#  ('Новофилёвский проезд', 8),
#  ('Молдавская улица', 8),
#  ('улица Пестеля', 8),
#  ('Россошанский проезд', 8),
#  ('Федоскинская улица', 8),
#  ('Россошанская улица', 8),
#  ('улица Гончарова', 8),
#  ('улица Двинцев', 8),
#  ('улица Грузинский Вал', 8),
#  ('Новый Берингов проезд', 8),
#  ('Харьковская улица', 8),
#  ('улица Добролюбова', 8),
#  ('Мясницкая улица', 8),
#  ('1-я улица Леонова', 8),
#  ('Большая Переяславская улица', 8),
#  ('улица Образцова', 8),
#  ('улица Новая Башиловка', 8),
#  ('Новоалексеевская улица', 8),
#  ('улица Олений Вал', 8),
#  ('Большая Ширяевская улица', 8),
#  ('Миллионная улица', 8),
#  ('Электрозаводский мост', 8),
#  ('Вельяминовская улица', 8),
#  ('Просторная улица', 8),
#  ('улица Ленинская Слобода', 8),
#  ('Потешная улица', 8),
#  ('Преображенская улица', 8),
#  ('улица Бориса Жигулёнкова', 8),
#  ('улица Шумкина', 8),
#  ('Курганская улица', 8),
#  ('Чусовская улица', 8),
#  ('Одесская улица', 8),
#  ('улица Старый Гай', 8),
#  ('Напольный проезд', 8),
#  ('Ясногорская улица', 8),
#  ('улица Айвазовского', 8),
#  ('улица Коновалова', 8),
#  ('Кузьминская улица', 8),
#  ('1-й Поперечный проезд', 8),
#  ('улица Зацепский Вал', 8),
#  ('Сормовская улица', 8),
#  ('Яузская улица', 8),
#  ('проезд Стройкомбината', 8),
#  ('Керченская улица', 8),
#  ('улица Шкулёва', 8),
#  ('Багратионовский проезд', 8),
#  ('Большая Андроньевская улица', 8),
#  ('Садовая-Спасская улица', 8),
#  ('Садовая-Самотёчная улица', 8),
#  ('Зубовский бульвар', 8),
#  ('улица Пржевальского', 8),
#  ('Новосущёвский переулок', 8),
#  ('улица Николая Химушина', 8),
#  ('Вильнюсская улица', 8),
#  ('улица Академика Хохлова', 8),
#  ('улица Паустовского', 8),
#  ('Конюшковская улица', 8),
#  ('улица Даниловский Вал', 8),
#  ('Ряжская улица', 8),
#  ('Новоспасский проезд', 8),
#  ('Луганская улица', 8),
#  ('улица Шверника', 8),
#  ('улица Гримау', 8),
#  ('Михневский проезд', 8),
#  ('Зеленодольская улица', 8),
#  ('Даниловская набережная', 8),
#  ('Юрьевский переулок', 8),
#  ('улица Орджоникидзе', 8),
#  ('Садовнический проезд', 8),
#  ('Устьинский проезд', 8),
#  ('Чистопрудный бульвар', 8),
#  ('улица Крупской', 8),
#  ('3-я Радиальная улица', 8),
#  ('34-й километр Московской Кольцевой Автодороги', 8),
#  ('32-й километр Московской Кольцевой Автодороги', 8),
#  ('проезд Одоевского', 8),
#  ('улица Раменки', 8),
#  ('улица Кедрова', 8),
#  ('7-я Кожуховская улица', 8),
#  ('Рочдельская улица', 8),
#  ('Елизаветинский переулок', 8),
#  ('3-й Сыромятнический переулок', 8),
#  ('1-я Магистральная улица', 8),
#  ('улица Комдива Орлова', 8),
#  ('1-й Митинский переулок', 8),
#  ('улица Академика Глушко', 8),
#  ('улица Знаменские Садки', 8),
#  ('Волынская улица', 8),
#  ('9-я Чоботовская аллея', 8),
#  ('Саранская улица', 8),
#  ('Лермонтовский проспект', 8),
#  ('Хвалынский бульвар', 8),
#  ('бульвар Адмирала Ушакова', 8),
#  ('1-я Рейсовая улица', 8),
#  ('Родионовская улица', 8),
#  ('улица Академика Полякова', 8),
#  ('2-й Кожуховский проезд', 8),
#  ('Цимлянская улица', 8),
#  ('улица Саломеи Нерис', 8),
#  ('улица Текстильщиков', 8),
#  ('Никулинский проезд', 8),
#  ('Комсомольская площадь', 8),
#  ('Середниковская улица', 8),
#  ('проезд № 474', 8),
#  ('улица Татьяны Макаровой', 8),
#  ('улица Панфилова', 8),
#  ('улица Бориса Петровского', 8),
#  ('9-я Северная линия', 8),
#  ('Новотушинский проезд', 8),
#  ('улица Маршала Прошлякова', 8),
#  ('Новодачное шоссе', 8),
#  ('Клинский проезд', 8),
#  ('проезд № 4922', 8),
#  ('Мурманский проезд', 8),
#  ('улица Юлиана Семёнова', 8),
#  ('улица Липовый Парк', 8),
#  ('Смирновская улица', 8),
#  ('Лечебная улица', 8),
#  ('Луховицкая улица', 8),
#  ('улица Светланова', 8),
#  ('Энергетическая улица', 8),
#  ('улица Речников', 8),
#  ('Ягодная улица', 8),
#  ('Бутовский тупик', 8),
#  ('улица Бориса Пастернака', 8),
#  ('улица Липчанского', 8),
#  ('улица Сретенка', 8),
#  ('площадь Тверская Застава', 8),
#  ('Садовая-Каретная улица', 8),
#  ('улица Самуила Маршака', 8),
#  ('Базовская улица', 8),
#  ('Новоданиловская набережная', 8),
#  ('улица Малая Дмитровка', 8),
#  ('улица Волхонка', 8),
#  ('18-й километр Московской Кольцевой Автодороги', 8),
#  ('улица Погодина', 8),
#  ('2-й Южнопортовый проезд', 8),
#  ('улица Пруд-Ключики', 8),
#  ('улица Академика Виноградова', 8),
#  ('улица Лавриненко', 8),
#  ('76-й километр Московской Кольцевой Автодороги', 8),
#  ('Сосновая улица', 6),
#  ('улица Лужники', 6),
#  ('Лужнецкая набережная', 6),
#  ('Рижская площадь', 6),
#  ('улица Саляма Адиля', 6),
#  ('Проспект Маршала Жукова', 6),
#  ('Песчаная площадь', 6),
#  ('Минусинская улица', 6),
#  ('Вишнёвая улица', 6),
#  ('площадь Академика Курчатова', 6),
#  ('площадь Новодевичьего Монастыря', 6),
#  ('проезд Соломенной Сторожки', 6),
#  ('улица Максимова', 6),
#  ('Весенняя улица', 6),
#  ('Ижорский проезд', 6),
#  ('улица Сергея Эйзенштейна', 6),
#  ('Отрадный проезд', 6),
#  ('Мелиховская улица', 6),
#  ('Псковская улица', 6),
#  ('Вяземская улица', 6),
#  ('улица Кубинка', 6),
#  ('Гвардейская улица', 6),
#  ('Староможайское шоссе', 6),
#  ('улица Серафимовича', 6),
#  ('Истринская улица', 6),
#  ('Заревый проезд', 6),
#  ('Селезнёвская улица', 6),
#  ('улица Намёткина', 6),
#  ('Страстной бульвар', 6),
#  ('Семёновская площадь', 6),
#  ('Малая Черкизовская улица', 6),
#  ('Игральная улица', 6),
#  ('Велозаводская улица', 6),
#  ('улица Мастеркова', 6),
#  ('2-й Полевой переулок', 6),
#  ('2-й Котляковский переулок', 6),
#  ('улица Достоевского', 6),
#  ('Иркутская улица', 6),
#  ('Снайперская улица', 6),
#  ('улица Уткина', 6),
#  ...]
